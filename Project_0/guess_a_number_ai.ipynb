# %% [markdown]
# # Game - Guess a number(AI)

# %%
from guess_a_number_ai import score_game
from guess_a_number_ai import random_predict

# %% [markdown]
# ## Random guess

# %%
score_game(random_predict)
# Out:
# You have guessed the number! It is = 38, number of attempts is 1.
# You have guessed the number! It is = 13, number of attempts is 5.
# You have guessed the number! It is = 73, number of attempts is 1.
# You have guessed the number! It is = 10, number of attempts is 1.
# You have guessed the number! It is = 76, number of attempts is 3.
# You have guessed the number! It is = 6, number of attempts is 2.
# You have guessed the number! It is = 80, number of attempts is 1.
# You have guessed the number! It is = 65, number of attempts is 1.
# You have guessed the number! It is = 17, number of attempts is 3.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 77, number of attempts is 1.
# You have guessed the number! It is = 72, number of attempts is 6.
# You have guessed the number! It is = 7, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 4.
# You have guessed the number! It is = 51, number of attempts is 1.
# You have guessed the number! It is = 21, number of attempts is 3.
# You have guessed the number! It is = 19, number of attempts is 2.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 12, number of attempts is 4.
# You have guessed the number! It is = 29, number of attempts is 2.
# You have guessed the number! It is = 30, number of attempts is 10.
# You have guessed the number! It is = 15, number of attempts is 1.
# You have guessed the number! It is = 51, number of attempts is 2.
# You have guessed the number! It is = 69, number of attempts is 4.
# You have guessed the number! It is = 88, number of attempts is 1.
# You have guessed the number! It is = 88, number of attempts is 3.
# You have guessed the number! It is = 95, number of attempts is 3.
# You have guessed the number! It is = 97, number of attempts is 2.
# You have guessed the number! It is = 87, number of attempts is 2.
# You have guessed the number! It is = 14, number of attempts is 3.
# You have guessed the number! It is = 10, number of attempts is 1.
# You have guessed the number! It is = 8, number of attempts is 4.
# You have guessed the number! It is = 64, number of attempts is 2.
# You have guessed the number! It is = 62, number of attempts is 2.
# You have guessed the number! It is = 23, number of attempts is 2.
# You have guessed the number! It is = 58, number of attempts is 4.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 61, number of attempts is 3.
# You have guessed the number! It is = 82, number of attempts is 4.
# You have guessed the number! It is = 9, number of attempts is 2.
# You have guessed the number! It is = 89, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 1.
# You have guessed the number! It is = 48, number of attempts is 15.
# You have guessed the number! It is = 73, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 3.
# You have guessed the number! It is = 72, number of attempts is 2.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 71, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 3.
# You have guessed the number! It is = 50, number of attempts is 6.
# You have guessed the number! It is = 58, number of attempts is 4.
# You have guessed the number! It is = 4, number of attempts is 2.
# You have guessed the number! It is = 69, number of attempts is 6.
# You have guessed the number! It is = 25, number of attempts is 4.
# You have guessed the number! It is = 44, number of attempts is 6.
# You have guessed the number! It is = 77, number of attempts is 1.
# You have guessed the number! It is = 27, number of attempts is 7.
# You have guessed the number! It is = 53, number of attempts is 1.
# You have guessed the number! It is = 81, number of attempts is 1.
# You have guessed the number! It is = 42, number of attempts is 21.
# You have guessed the number! It is = 83, number of attempts is 2.
# You have guessed the number! It is = 16, number of attempts is 2.
# You have guessed the number! It is = 65, number of attempts is 1.
# You have guessed the number! It is = 69, number of attempts is 6.
# You have guessed the number! It is = 26, number of attempts is 1.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 88, number of attempts is 1.
# You have guessed the number! It is = 8, number of attempts is 3.
# You have guessed the number! It is = 27, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 3.
# You have guessed the number! It is = 10, number of attempts is 1.
# You have guessed the number! It is = 68, number of attempts is 2.
# You have guessed the number! It is = 24, number of attempts is 2.
# You have guessed the number! It is = 28, number of attempts is 1.
# You have guessed the number! It is = 38, number of attempts is 1.
# You have guessed the number! It is = 58, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 2.
# You have guessed the number! It is = 39, number of attempts is 8.
# You have guessed the number! It is = 9, number of attempts is 1.
# You have guessed the number! It is = 33, number of attempts is 7.
# You have guessed the number! It is = 35, number of attempts is 2.
# You have guessed the number! It is = 11, number of attempts is 1.
# You have guessed the number! It is = 24, number of attempts is 7.
# You have guessed the number! It is = 16, number of attempts is 1.
# You have guessed the number! It is = 88, number of attempts is 2.
# You have guessed the number! It is = 26, number of attempts is 1.
# You have guessed the number! It is = 72, number of attempts is 5.
# You have guessed the number! It is = 93, number of attempts is 1.
# You have guessed the number! It is = 75, number of attempts is 1.
# You have guessed the number! It is = 63, number of attempts is 10.
# You have guessed the number! It is = 47, number of attempts is 4.
# You have guessed the number! It is = 33, number of attempts is 2.
# You have guessed the number! It is = 89, number of attempts is 5.
# You have guessed the number! It is = 24, number of attempts is 3.
# You have guessed the number! It is = 56, number of attempts is 4.
# You have guessed the number! It is = 66, number of attempts is 7.
# You have guessed the number! It is = 78, number of attempts is 2.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 7, number of attempts is 1.
# You have guessed the number! It is = 53, number of attempts is 9.
# You have guessed the number! It is = 86, number of attempts is 3.
# You have guessed the number! It is = 71, number of attempts is 2.
# You have guessed the number! It is = 3, number of attempts is 1.
# You have guessed the number! It is = 77, number of attempts is 2.
# You have guessed the number! It is = 92, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 2.
# You have guessed the number! It is = 76, number of attempts is 4.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 2.
# You have guessed the number! It is = 73, number of attempts is 10.
# You have guessed the number! It is = 76, number of attempts is 5.
# You have guessed the number! It is = 77, number of attempts is 2.
# You have guessed the number! It is = 44, number of attempts is 13.
# You have guessed the number! It is = 21, number of attempts is 3.
# You have guessed the number! It is = 31, number of attempts is 5.
# You have guessed the number! It is = 37, number of attempts is 8.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 46, number of attempts is 1.
# You have guessed the number! It is = 69, number of attempts is 1.
# You have guessed the number! It is = 58, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 3.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 1.
# You have guessed the number! It is = 11, number of attempts is 1.
# You have guessed the number! It is = 24, number of attempts is 4.
# You have guessed the number! It is = 82, number of attempts is 4.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 25, number of attempts is 2.
# You have guessed the number! It is = 75, number of attempts is 1.
# You have guessed the number! It is = 93, number of attempts is 1.
# You have guessed the number! It is = 21, number of attempts is 2.
# You have guessed the number! It is = 33, number of attempts is 1.
# You have guessed the number! It is = 13, number of attempts is 4.
# You have guessed the number! It is = 66, number of attempts is 1.
# You have guessed the number! It is = 95, number of attempts is 3.
# You have guessed the number! It is = 61, number of attempts is 8.
# You have guessed the number! It is = 25, number of attempts is 2.
# You have guessed the number! It is = 83, number of attempts is 3.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 3, number of attempts is 1.
# You have guessed the number! It is = 93, number of attempts is 1.
# You have guessed the number! It is = 99, number of attempts is 2.
# You have guessed the number! It is = 11, number of attempts is 2.
# You have guessed the number! It is = 55, number of attempts is 2.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 1.
# You have guessed the number! It is = 71, number of attempts is 4.
# You have guessed the number! It is = 67, number of attempts is 5.
# You have guessed the number! It is = 72, number of attempts is 1.
# You have guessed the number! It is = 49, number of attempts is 3.
# You have guessed the number! It is = 55, number of attempts is 1.
# You have guessed the number! It is = 16, number of attempts is 3.
# You have guessed the number! It is = 6, number of attempts is 1.
# You have guessed the number! It is = 18, number of attempts is 1.
# You have guessed the number! It is = 43, number of attempts is 3.
# You have guessed the number! It is = 21, number of attempts is 1.
# You have guessed the number! It is = 49, number of attempts is 3.
# You have guessed the number! It is = 23, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 54, number of attempts is 8.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 11, number of attempts is 4.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 56, number of attempts is 3.
# You have guessed the number! It is = 62, number of attempts is 4.
# You have guessed the number! It is = 57, number of attempts is 8.
# You have guessed the number! It is = 90, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 8.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 2.
# You have guessed the number! It is = 14, number of attempts is 1.
# You have guessed the number! It is = 85, number of attempts is 2.
# You have guessed the number! It is = 44, number of attempts is 1.
# You have guessed the number! It is = 7, number of attempts is 3.
# You have guessed the number! It is = 78, number of attempts is 2.
# You have guessed the number! It is = 57, number of attempts is 1.
# You have guessed the number! It is = 60, number of attempts is 6.
# You have guessed the number! It is = 16, number of attempts is 4.
# You have guessed the number! It is = 25, number of attempts is 2.
# You have guessed the number! It is = 10, number of attempts is 5.
# You have guessed the number! It is = 67, number of attempts is 1.
# You have guessed the number! It is = 72, number of attempts is 3.
# You have guessed the number! It is = 54, number of attempts is 3.
# You have guessed the number! It is = 70, number of attempts is 4.
# You have guessed the number! It is = 37, number of attempts is 3.
# You have guessed the number! It is = 22, number of attempts is 7.
# You have guessed the number! It is = 41, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 4.
# You have guessed the number! It is = 92, number of attempts is 4.
# You have guessed the number! It is = 50, number of attempts is 1.
# You have guessed the number! It is = 48, number of attempts is 11.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 41, number of attempts is 3.
# You have guessed the number! It is = 79, number of attempts is 3.
# You have guessed the number! It is = 46, number of attempts is 2.
# You have guessed the number! It is = 88, number of attempts is 1.
# You have guessed the number! It is = 17, number of attempts is 3.
# You have guessed the number! It is = 29, number of attempts is 4.
# You have guessed the number! It is = 46, number of attempts is 7.
# You have guessed the number! It is = 68, number of attempts is 2.
# You have guessed the number! It is = 67, number of attempts is 2.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 47, number of attempts is 5.
# You have guessed the number! It is = 1, number of attempts is 3.
# You have guessed the number! It is = 30, number of attempts is 12.
# You have guessed the number! It is = 64, number of attempts is 4.
# You have guessed the number! It is = 76, number of attempts is 5.
# You have guessed the number! It is = 36, number of attempts is 2.
# You have guessed the number! It is = 54, number of attempts is 3.
# You have guessed the number! It is = 94, number of attempts is 5.
# You have guessed the number! It is = 34, number of attempts is 1.
# You have guessed the number! It is = 3, number of attempts is 1.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 5.
# You have guessed the number! It is = 49, number of attempts is 7.
# You have guessed the number! It is = 55, number of attempts is 2.
# You have guessed the number! It is = 33, number of attempts is 6.
# You have guessed the number! It is = 29, number of attempts is 2.
# You have guessed the number! It is = 56, number of attempts is 5.
# You have guessed the number! It is = 83, number of attempts is 2.
# You have guessed the number! It is = 32, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 3.
# You have guessed the number! It is = 95, number of attempts is 2.
# You have guessed the number! It is = 75, number of attempts is 3.
# You have guessed the number! It is = 9, number of attempts is 7.
# You have guessed the number! It is = 100, number of attempts is 1.
# You have guessed the number! It is = 33, number of attempts is 4.
# You have guessed the number! It is = 9, number of attempts is 2.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 51, number of attempts is 2.
# You have guessed the number! It is = 80, number of attempts is 2.
# You have guessed the number! It is = 42, number of attempts is 1.
# You have guessed the number! It is = 65, number of attempts is 2.
# You have guessed the number! It is = 84, number of attempts is 2.
# You have guessed the number! It is = 25, number of attempts is 2.
# You have guessed the number! It is = 21, number of attempts is 2.
# You have guessed the number! It is = 45, number of attempts is 15.
# You have guessed the number! It is = 16, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 92, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 1.
# You have guessed the number! It is = 20, number of attempts is 3.
# You have guessed the number! It is = 27, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 3.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 100, number of attempts is 1.
# You have guessed the number! It is = 54, number of attempts is 8.
# You have guessed the number! It is = 48, number of attempts is 5.
# You have guessed the number! It is = 61, number of attempts is 10.
# You have guessed the number! It is = 35, number of attempts is 5.
# You have guessed the number! It is = 33, number of attempts is 1.
# You have guessed the number! It is = 20, number of attempts is 2.
# You have guessed the number! It is = 68, number of attempts is 3.
# You have guessed the number! It is = 25, number of attempts is 3.
# You have guessed the number! It is = 84, number of attempts is 4.
# You have guessed the number! It is = 95, number of attempts is 1.
# You have guessed the number! It is = 39, number of attempts is 7.
# You have guessed the number! It is = 48, number of attempts is 2.
# You have guessed the number! It is = 6, number of attempts is 3.
# You have guessed the number! It is = 80, number of attempts is 1.
# You have guessed the number! It is = 64, number of attempts is 2.
# You have guessed the number! It is = 88, number of attempts is 4.
# You have guessed the number! It is = 33, number of attempts is 4.
# You have guessed the number! It is = 43, number of attempts is 1.
# You have guessed the number! It is = 75, number of attempts is 3.
# You have guessed the number! It is = 67, number of attempts is 4.
# You have guessed the number! It is = 89, number of attempts is 2.
# You have guessed the number! It is = 99, number of attempts is 4.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 18, number of attempts is 1.
# You have guessed the number! It is = 69, number of attempts is 7.
# You have guessed the number! It is = 65, number of attempts is 1.
# You have guessed the number! It is = 61, number of attempts is 1.
# You have guessed the number! It is = 79, number of attempts is 2.
# You have guessed the number! It is = 18, number of attempts is 3.
# You have guessed the number! It is = 40, number of attempts is 10.
# You have guessed the number! It is = 36, number of attempts is 1.
# You have guessed the number! It is = 82, number of attempts is 9.
# You have guessed the number! It is = 29, number of attempts is 2.
# You have guessed the number! It is = 23, number of attempts is 9.
# You have guessed the number! It is = 39, number of attempts is 4.
# You have guessed the number! It is = 42, number of attempts is 1.
# You have guessed the number! It is = 75, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 2.
# You have guessed the number! It is = 71, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 2.
# You have guessed the number! It is = 49, number of attempts is 2.
# You have guessed the number! It is = 51, number of attempts is 6.
# You have guessed the number! It is = 63, number of attempts is 3.
# You have guessed the number! It is = 45, number of attempts is 3.
# You have guessed the number! It is = 55, number of attempts is 6.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 4.
# You have guessed the number! It is = 17, number of attempts is 3.
# You have guessed the number! It is = 20, number of attempts is 1.
# You have guessed the number! It is = 10, number of attempts is 3.
# You have guessed the number! It is = 93, number of attempts is 2.
# You have guessed the number! It is = 52, number of attempts is 3.
# You have guessed the number! It is = 11, number of attempts is 2.
# You have guessed the number! It is = 69, number of attempts is 4.
# You have guessed the number! It is = 24, number of attempts is 12.
# You have guessed the number! It is = 15, number of attempts is 1.
# You have guessed the number! It is = 64, number of attempts is 8.
# You have guessed the number! It is = 22, number of attempts is 3.
# You have guessed the number! It is = 47, number of attempts is 8.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 57, number of attempts is 7.
# You have guessed the number! It is = 89, number of attempts is 1.
# You have guessed the number! It is = 81, number of attempts is 1.
# You have guessed the number! It is = 47, number of attempts is 3.
# You have guessed the number! It is = 55, number of attempts is 11.
# You have guessed the number! It is = 80, number of attempts is 1.
# You have guessed the number! It is = 72, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 16, number of attempts is 2.
# You have guessed the number! It is = 26, number of attempts is 2.
# You have guessed the number! It is = 54, number of attempts is 41.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 59, number of attempts is 3.
# You have guessed the number! It is = 86, number of attempts is 1.
# You have guessed the number! It is = 30, number of attempts is 1.
# You have guessed the number! It is = 45, number of attempts is 3.
# You have guessed the number! It is = 38, number of attempts is 2.
# You have guessed the number! It is = 23, number of attempts is 2.
# You have guessed the number! It is = 92, number of attempts is 2.
# You have guessed the number! It is = 55, number of attempts is 1.
# You have guessed the number! It is = 77, number of attempts is 1.
# You have guessed the number! It is = 13, number of attempts is 3.
# You have guessed the number! It is = 60, number of attempts is 8.
# You have guessed the number! It is = 27, number of attempts is 7.
# You have guessed the number! It is = 77, number of attempts is 1.
# You have guessed the number! It is = 72, number of attempts is 10.
# You have guessed the number! It is = 88, number of attempts is 1.
# You have guessed the number! It is = 40, number of attempts is 1.
# You have guessed the number! It is = 44, number of attempts is 4.
# You have guessed the number! It is = 77, number of attempts is 4.
# You have guessed the number! It is = 39, number of attempts is 3.
# You have guessed the number! It is = 92, number of attempts is 1.
# You have guessed the number! It is = 70, number of attempts is 3.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 34, number of attempts is 4.
# You have guessed the number! It is = 44, number of attempts is 3.
# You have guessed the number! It is = 27, number of attempts is 1.
# You have guessed the number! It is = 57, number of attempts is 2.
# You have guessed the number! It is = 70, number of attempts is 1.
# You have guessed the number! It is = 74, number of attempts is 4.
# You have guessed the number! It is = 53, number of attempts is 1.
# You have guessed the number! It is = 90, number of attempts is 1.
# You have guessed the number! It is = 28, number of attempts is 2.
# You have guessed the number! It is = 44, number of attempts is 10.
# You have guessed the number! It is = 2, number of attempts is 2.
# You have guessed the number! It is = 83, number of attempts is 1.
# You have guessed the number! It is = 95, number of attempts is 4.
# You have guessed the number! It is = 97, number of attempts is 3.
# You have guessed the number! It is = 27, number of attempts is 1.
# You have guessed the number! It is = 85, number of attempts is 3.
# You have guessed the number! It is = 31, number of attempts is 1.
# You have guessed the number! It is = 65, number of attempts is 6.
# You have guessed the number! It is = 23, number of attempts is 7.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 53, number of attempts is 9.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 71, number of attempts is 1.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 40, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 2.
# You have guessed the number! It is = 49, number of attempts is 5.
# You have guessed the number! It is = 62, number of attempts is 1.
# You have guessed the number! It is = 71, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 4.
# You have guessed the number! It is = 37, number of attempts is 1.
# You have guessed the number! It is = 24, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 2.
# You have guessed the number! It is = 67, number of attempts is 10.
# You have guessed the number! It is = 93, number of attempts is 2.
# You have guessed the number! It is = 96, number of attempts is 1.
# You have guessed the number! It is = 54, number of attempts is 3.
# You have guessed the number! It is = 10, number of attempts is 4.
# You have guessed the number! It is = 42, number of attempts is 2.
# You have guessed the number! It is = 58, number of attempts is 5.
# You have guessed the number! It is = 89, number of attempts is 3.
# You have guessed the number! It is = 94, number of attempts is 2.
# You have guessed the number! It is = 77, number of attempts is 9.
# You have guessed the number! It is = 83, number of attempts is 1.
# You have guessed the number! It is = 12, number of attempts is 2.
# You have guessed the number! It is = 37, number of attempts is 2.
# You have guessed the number! It is = 17, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 85, number of attempts is 3.
# You have guessed the number! It is = 58, number of attempts is 5.
# You have guessed the number! It is = 36, number of attempts is 6.
# You have guessed the number! It is = 42, number of attempts is 10.
# You have guessed the number! It is = 82, number of attempts is 4.
# You have guessed the number! It is = 3, number of attempts is 4.
# You have guessed the number! It is = 86, number of attempts is 2.
# You have guessed the number! It is = 94, number of attempts is 1.
# You have guessed the number! It is = 37, number of attempts is 4.
# You have guessed the number! It is = 47, number of attempts is 2.
# You have guessed the number! It is = 81, number of attempts is 2.
# You have guessed the number! It is = 28, number of attempts is 2.
# You have guessed the number! It is = 73, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 2.
# You have guessed the number! It is = 3, number of attempts is 1.
# You have guessed the number! It is = 100, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 1.
# You have guessed the number! It is = 42, number of attempts is 2.
# You have guessed the number! It is = 37, number of attempts is 19.
# You have guessed the number! It is = 41, number of attempts is 9.
# You have guessed the number! It is = 19, number of attempts is 3.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 39, number of attempts is 1.
# You have guessed the number! It is = 64, number of attempts is 5.
# You have guessed the number! It is = 47, number of attempts is 1.
# You have guessed the number! It is = 90, number of attempts is 6.
# You have guessed the number! It is = 3, number of attempts is 1.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 4.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 76, number of attempts is 2.
# You have guessed the number! It is = 59, number of attempts is 2.
# You have guessed the number! It is = 43, number of attempts is 3.
# You have guessed the number! It is = 27, number of attempts is 2.
# You have guessed the number! It is = 22, number of attempts is 2.
# You have guessed the number! It is = 59, number of attempts is 1.
# You have guessed the number! It is = 17, number of attempts is 2.
# You have guessed the number! It is = 93, number of attempts is 1.
# You have guessed the number! It is = 38, number of attempts is 9.
# You have guessed the number! It is = 12, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 4.
# You have guessed the number! It is = 7, number of attempts is 1.
# You have guessed the number! It is = 97, number of attempts is 7.
# You have guessed the number! It is = 15, number of attempts is 1.
# You have guessed the number! It is = 88, number of attempts is 1.
# You have guessed the number! It is = 76, number of attempts is 6.
# You have guessed the number! It is = 36, number of attempts is 2.
# You have guessed the number! It is = 64, number of attempts is 1.
# You have guessed the number! It is = 33, number of attempts is 4.
# You have guessed the number! It is = 92, number of attempts is 1.
# You have guessed the number! It is = 50, number of attempts is 2.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 2.
# You have guessed the number! It is = 71, number of attempts is 5.
# You have guessed the number! It is = 37, number of attempts is 3.
# You have guessed the number! It is = 19, number of attempts is 1.
# You have guessed the number! It is = 28, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 2.
# You have guessed the number! It is = 53, number of attempts is 9.
# You have guessed the number! It is = 95, number of attempts is 1.
# You have guessed the number! It is = 51, number of attempts is 4.
# You have guessed the number! It is = 47, number of attempts is 2.
# You have guessed the number! It is = 8, number of attempts is 4.
# You have guessed the number! It is = 86, number of attempts is 2.
# You have guessed the number! It is = 17, number of attempts is 1.
# You have guessed the number! It is = 30, number of attempts is 3.
# You have guessed the number! It is = 12, number of attempts is 1.
# You have guessed the number! It is = 62, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 9, number of attempts is 4.
# You have guessed the number! It is = 41, number of attempts is 2.
# You have guessed the number! It is = 49, number of attempts is 9.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 24, number of attempts is 4.
# You have guessed the number! It is = 67, number of attempts is 3.
# You have guessed the number! It is = 93, number of attempts is 1.
# You have guessed the number! It is = 65, number of attempts is 1.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 18, number of attempts is 3.
# You have guessed the number! It is = 34, number of attempts is 5.
# You have guessed the number! It is = 11, number of attempts is 3.
# You have guessed the number! It is = 29, number of attempts is 8.
# You have guessed the number! It is = 76, number of attempts is 2.
# You have guessed the number! It is = 6, number of attempts is 1.
# You have guessed the number! It is = 82, number of attempts is 1.
# You have guessed the number! It is = 6, number of attempts is 2.
# You have guessed the number! It is = 43, number of attempts is 13.
# You have guessed the number! It is = 87, number of attempts is 2.
# You have guessed the number! It is = 53, number of attempts is 6.
# You have guessed the number! It is = 58, number of attempts is 12.
# You have guessed the number! It is = 57, number of attempts is 1.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 88, number of attempts is 2.
# You have guessed the number! It is = 82, number of attempts is 2.
# You have guessed the number! It is = 11, number of attempts is 2.
# You have guessed the number! It is = 73, number of attempts is 1.
# You have guessed the number! It is = 49, number of attempts is 1.
# You have guessed the number! It is = 20, number of attempts is 5.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 8.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 17, number of attempts is 4.
# You have guessed the number! It is = 5, number of attempts is 1.
# You have guessed the number! It is = 89, number of attempts is 1.
# You have guessed the number! It is = 28, number of attempts is 2.
# You have guessed the number! It is = 51, number of attempts is 3.
# You have guessed the number! It is = 69, number of attempts is 8.
# You have guessed the number! It is = 4, number of attempts is 4.
# You have guessed the number! It is = 59, number of attempts is 2.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 3, number of attempts is 3.
# You have guessed the number! It is = 77, number of attempts is 4.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 97, number of attempts is 2.
# You have guessed the number! It is = 62, number of attempts is 9.
# You have guessed the number! It is = 16, number of attempts is 1.
# You have guessed the number! It is = 75, number of attempts is 2.
# You have guessed the number! It is = 13, number of attempts is 2.
# You have guessed the number! It is = 19, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 8.
# You have guessed the number! It is = 60, number of attempts is 8.
# You have guessed the number! It is = 6, number of attempts is 1.
# You have guessed the number! It is = 17, number of attempts is 5.
# You have guessed the number! It is = 96, number of attempts is 1.
# You have guessed the number! It is = 97, number of attempts is 2.
# You have guessed the number! It is = 61, number of attempts is 3.
# You have guessed the number! It is = 44, number of attempts is 2.
# You have guessed the number! It is = 32, number of attempts is 4.
# You have guessed the number! It is = 100, number of attempts is 1.
# You have guessed the number! It is = 45, number of attempts is 1.
# You have guessed the number! It is = 25, number of attempts is 2.
# You have guessed the number! It is = 63, number of attempts is 12.
# You have guessed the number! It is = 80, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 3.
# You have guessed the number! It is = 20, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 34, number of attempts is 3.
# You have guessed the number! It is = 5, number of attempts is 2.
# You have guessed the number! It is = 40, number of attempts is 1.
# You have guessed the number! It is = 68, number of attempts is 2.
# You have guessed the number! It is = 35, number of attempts is 1.
# You have guessed the number! It is = 35, number of attempts is 1.
# You have guessed the number! It is = 43, number of attempts is 3.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 1.
# You have guessed the number! It is = 39, number of attempts is 3.
# You have guessed the number! It is = 49, number of attempts is 5.
# You have guessed the number! It is = 82, number of attempts is 2.
# You have guessed the number! It is = 6, number of attempts is 1.
# You have guessed the number! It is = 92, number of attempts is 5.
# You have guessed the number! It is = 9, number of attempts is 1.
# You have guessed the number! It is = 41, number of attempts is 2.
# You have guessed the number! It is = 70, number of attempts is 6.
# You have guessed the number! It is = 6, number of attempts is 2.
# You have guessed the number! It is = 8, number of attempts is 2.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 38, number of attempts is 5.
# You have guessed the number! It is = 79, number of attempts is 7.
# You have guessed the number! It is = 34, number of attempts is 1.
# You have guessed the number! It is = 28, number of attempts is 3.
# You have guessed the number! It is = 52, number of attempts is 7.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 1.
# You have guessed the number! It is = 44, number of attempts is 6.
# You have guessed the number! It is = 47, number of attempts is 3.
# You have guessed the number! It is = 10, number of attempts is 5.
# You have guessed the number! It is = 68, number of attempts is 1.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 68, number of attempts is 2.
# You have guessed the number! It is = 55, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 64, number of attempts is 8.
# You have guessed the number! It is = 100, number of attempts is 1.
# You have guessed the number! It is = 81, number of attempts is 3.
# You have guessed the number! It is = 29, number of attempts is 2.
# You have guessed the number! It is = 38, number of attempts is 1.
# You have guessed the number! It is = 65, number of attempts is 3.
# You have guessed the number! It is = 38, number of attempts is 1.
# You have guessed the number! It is = 94, number of attempts is 1.
# You have guessed the number! It is = 19, number of attempts is 2.
# You have guessed the number! It is = 79, number of attempts is 2.
# You have guessed the number! It is = 71, number of attempts is 3.
# You have guessed the number! It is = 93, number of attempts is 2.
# You have guessed the number! It is = 53, number of attempts is 4.
# You have guessed the number! It is = 11, number of attempts is 1.
# You have guessed the number! It is = 33, number of attempts is 2.
# You have guessed the number! It is = 47, number of attempts is 2.
# You have guessed the number! It is = 64, number of attempts is 3.
# You have guessed the number! It is = 94, number of attempts is 1.
# You have guessed the number! It is = 19, number of attempts is 1.
# You have guessed the number! It is = 37, number of attempts is 19.
# You have guessed the number! It is = 30, number of attempts is 1.
# You have guessed the number! It is = 40, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 4.
# You have guessed the number! It is = 55, number of attempts is 1.
# You have guessed the number! It is = 30, number of attempts is 2.
# You have guessed the number! It is = 56, number of attempts is 7.
# You have guessed the number! It is = 91, number of attempts is 2.
# You have guessed the number! It is = 28, number of attempts is 7.
# You have guessed the number! It is = 61, number of attempts is 8.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 18, number of attempts is 5.
# You have guessed the number! It is = 72, number of attempts is 1.
# You have guessed the number! It is = 92, number of attempts is 1.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 4.
# You have guessed the number! It is = 57, number of attempts is 6.
# You have guessed the number! It is = 52, number of attempts is 6.
# You have guessed the number! It is = 33, number of attempts is 17.
# You have guessed the number! It is = 77, number of attempts is 8.
# You have guessed the number! It is = 63, number of attempts is 3.
# You have guessed the number! It is = 52, number of attempts is 2.
# You have guessed the number! It is = 97, number of attempts is 2.
# You have guessed the number! It is = 31, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 1.
# You have guessed the number! It is = 6, number of attempts is 1.
# You have guessed the number! It is = 92, number of attempts is 7.
# You have guessed the number! It is = 96, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 3.
# You have guessed the number! It is = 77, number of attempts is 2.
# You have guessed the number! It is = 23, number of attempts is 1.
# You have guessed the number! It is = 19, number of attempts is 1.
# You have guessed the number! It is = 94, number of attempts is 1.
# You have guessed the number! It is = 30, number of attempts is 4.
# You have guessed the number! It is = 19, number of attempts is 1.
# You have guessed the number! It is = 53, number of attempts is 2.
# You have guessed the number! It is = 32, number of attempts is 1.
# You have guessed the number! It is = 50, number of attempts is 7.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 4.
# You have guessed the number! It is = 94, number of attempts is 1.
# You have guessed the number! It is = 46, number of attempts is 4.
# You have guessed the number! It is = 52, number of attempts is 10.
# You have guessed the number! It is = 87, number of attempts is 3.
# You have guessed the number! It is = 16, number of attempts is 2.
# You have guessed the number! It is = 72, number of attempts is 1.
# You have guessed the number! It is = 49, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 4.
# You have guessed the number! It is = 84, number of attempts is 2.
# You have guessed the number! It is = 28, number of attempts is 1.
# You have guessed the number! It is = 44, number of attempts is 7.
# You have guessed the number! It is = 20, number of attempts is 8.
# You have guessed the number! It is = 80, number of attempts is 2.
# You have guessed the number! It is = 71, number of attempts is 1.
# You have guessed the number! It is = 89, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 2.
# You have guessed the number! It is = 12, number of attempts is 1.
# You have guessed the number! It is = 66, number of attempts is 1.
# You have guessed the number! It is = 94, number of attempts is 1.
# You have guessed the number! It is = 16, number of attempts is 1.
# You have guessed the number! It is = 52, number of attempts is 2.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 1.
# You have guessed the number! It is = 46, number of attempts is 1.
# You have guessed the number! It is = 64, number of attempts is 2.
# You have guessed the number! It is = 43, number of attempts is 10.
# You have guessed the number! It is = 23, number of attempts is 3.
# You have guessed the number! It is = 83, number of attempts is 1.
# You have guessed the number! It is = 41, number of attempts is 9.
# You have guessed the number! It is = 45, number of attempts is 5.
# You have guessed the number! It is = 17, number of attempts is 2.
# You have guessed the number! It is = 18, number of attempts is 3.
# You have guessed the number! It is = 89, number of attempts is 7.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 2.
# You have guessed the number! It is = 72, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 2.
# You have guessed the number! It is = 37, number of attempts is 6.
# You have guessed the number! It is = 27, number of attempts is 2.
# You have guessed the number! It is = 33, number of attempts is 3.
# You have guessed the number! It is = 2, number of attempts is 2.
# You have guessed the number! It is = 49, number of attempts is 18.
# You have guessed the number! It is = 89, number of attempts is 1.
# You have guessed the number! It is = 23, number of attempts is 3.
# You have guessed the number! It is = 35, number of attempts is 6.
# You have guessed the number! It is = 95, number of attempts is 2.
# You have guessed the number! It is = 22, number of attempts is 1.
# You have guessed the number! It is = 69, number of attempts is 1.
# You have guessed the number! It is = 68, number of attempts is 2.
# You have guessed the number! It is = 49, number of attempts is 8.
# You have guessed the number! It is = 19, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 12, number of attempts is 4.
# You have guessed the number! It is = 12, number of attempts is 2.
# You have guessed the number! It is = 53, number of attempts is 1.
# You have guessed the number! It is = 77, number of attempts is 3.
# You have guessed the number! It is = 69, number of attempts is 3.
# You have guessed the number! It is = 46, number of attempts is 1.
# You have guessed the number! It is = 65, number of attempts is 3.
# You have guessed the number! It is = 90, number of attempts is 2.
# You have guessed the number! It is = 41, number of attempts is 5.
# You have guessed the number! It is = 8, number of attempts is 3.
# You have guessed the number! It is = 8, number of attempts is 4.
# You have guessed the number! It is = 34, number of attempts is 1.
# You have guessed the number! It is = 59, number of attempts is 8.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 35, number of attempts is 3.
# You have guessed the number! It is = 5, number of attempts is 2.
# You have guessed the number! It is = 6, number of attempts is 2.
# You have guessed the number! It is = 62, number of attempts is 2.
# You have guessed the number! It is = 51, number of attempts is 1.
# You have guessed the number! It is = 77, number of attempts is 2.
# You have guessed the number! It is = 46, number of attempts is 4.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 3.
# You have guessed the number! It is = 93, number of attempts is 2.
# You have guessed the number! It is = 72, number of attempts is 2.
# You have guessed the number! It is = 93, number of attempts is 2.
# You have guessed the number! It is = 26, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 2.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 1.
# You have guessed the number! It is = 39, number of attempts is 9.
# You have guessed the number! It is = 86, number of attempts is 1.
# You have guessed the number! It is = 28, number of attempts is 2.
# You have guessed the number! It is = 39, number of attempts is 3.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 34, number of attempts is 5.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 32, number of attempts is 2.
# You have guessed the number! It is = 39, number of attempts is 2.
# You have guessed the number! It is = 29, number of attempts is 1.
# You have guessed the number! It is = 76, number of attempts is 5.
# You have guessed the number! It is = 100, number of attempts is 3.
# You have guessed the number! It is = 32, number of attempts is 1.
# You have guessed the number! It is = 52, number of attempts is 2.
# ...
# You have guessed the number! It is = 7, number of attempts is 1.
# You have guessed the number! It is = 66, number of attempts is 4.
# You have guessed the number! It is = 52, number of attempts is 1.
# You have guessed the number! It is = 32, number of attempts is 2.
# You have guessed the number! It is = 8, number of attempts is 1.
# You have guessed the number! It is = 14, number of attempts is 3.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 29, number of attempts is 1.
# You have guessed the number! It is = 16, number of attempts is 3.
# You have guessed the number! It is = 30, number of attempts is 8.
# You have guessed the number! It is = 67, number of attempts is 3.
# You have guessed the number! It is = 62, number of attempts is 7.
# You have guessed the number! It is = 84, number of attempts is 2.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 59, number of attempts is 18.
# You have guessed the number! It is = 83, number of attempts is 2.
# You have guessed the number! It is = 35, number of attempts is 5.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 58, number of attempts is 4.
# You have guessed the number! It is = 97, number of attempts is 2.
# You have guessed the number! It is = 50, number of attempts is 3.
# You have guessed the number! It is = 47, number of attempts is 8.
# You have guessed the number! It is = 84, number of attempts is 1.
# You have guessed the number! It is = 42, number of attempts is 2.
# You have guessed the number! It is = 21, number of attempts is 2.
# You have guessed the number! It is = 41, number of attempts is 1.
# You have guessed the number! It is = 51, number of attempts is 4.
# You have guessed the number! It is = 5, number of attempts is 1.
# You have guessed the number! It is = 10, number of attempts is 4.
# You have guessed the number! It is = 1, number of attempts is 4.
# You have guessed the number! It is = 91, number of attempts is 2.
# You have guessed the number! It is = 22, number of attempts is 1.
# You have guessed the number! It is = 75, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 1.
# You have guessed the number! It is = 34, number of attempts is 1.
# You have guessed the number! It is = 39, number of attempts is 1.
# You have guessed the number! It is = 38, number of attempts is 2.
# You have guessed the number! It is = 44, number of attempts is 5.
# You have guessed the number! It is = 34, number of attempts is 3.
# You have guessed the number! It is = 96, number of attempts is 2.
# You have guessed the number! It is = 42, number of attempts is 2.
# You have guessed the number! It is = 72, number of attempts is 2.
# You have guessed the number! It is = 70, number of attempts is 2.
# You have guessed the number! It is = 71, number of attempts is 1.
# You have guessed the number! It is = 24, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 2.
# You have guessed the number! It is = 40, number of attempts is 6.
# You have guessed the number! It is = 32, number of attempts is 1.
# You have guessed the number! It is = 38, number of attempts is 2.
# You have guessed the number! It is = 39, number of attempts is 1.
# You have guessed the number! It is = 57, number of attempts is 3.
# You have guessed the number! It is = 88, number of attempts is 2.
# You have guessed the number! It is = 29, number of attempts is 1.
# You have guessed the number! It is = 37, number of attempts is 2.
# You have guessed the number! It is = 67, number of attempts is 1.
# You have guessed the number! It is = 11, number of attempts is 2.
# You have guessed the number! It is = 85, number of attempts is 1.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 17, number of attempts is 1.
# You have guessed the number! It is = 31, number of attempts is 3.
# You have guessed the number! It is = 4, number of attempts is 2.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 60, number of attempts is 10.
# You have guessed the number! It is = 54, number of attempts is 7.
# You have guessed the number! It is = 70, number of attempts is 2.
# You have guessed the number! It is = 50, number of attempts is 3.
# You have guessed the number! It is = 75, number of attempts is 2.
# You have guessed the number! It is = 47, number of attempts is 11.
# You have guessed the number! It is = 28, number of attempts is 2.
# You have guessed the number! It is = 34, number of attempts is 1.
# You have guessed the number! It is = 73, number of attempts is 3.
# You have guessed the number! It is = 69, number of attempts is 11.
# You have guessed the number! It is = 40, number of attempts is 3.
# You have guessed the number! It is = 33, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 2.
# You have guessed the number! It is = 8, number of attempts is 5.
# You have guessed the number! It is = 34, number of attempts is 3.
# You have guessed the number! It is = 63, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 2.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 44, number of attempts is 6.
# You have guessed the number! It is = 62, number of attempts is 1.
# You have guessed the number! It is = 86, number of attempts is 1.
# You have guessed the number! It is = 37, number of attempts is 2.
# You have guessed the number! It is = 13, number of attempts is 6.
# You have guessed the number! It is = 54, number of attempts is 3.
# You have guessed the number! It is = 27, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 5.
# You have guessed the number! It is = 100, number of attempts is 3.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 100, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 7.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 42, number of attempts is 1.
# You have guessed the number! It is = 56, number of attempts is 5.
# You have guessed the number! It is = 56, number of attempts is 5.
# You have guessed the number! It is = 65, number of attempts is 2.
# You have guessed the number! It is = 16, number of attempts is 7.
# You have guessed the number! It is = 93, number of attempts is 1.
# You have guessed the number! It is = 41, number of attempts is 3.
# You have guessed the number! It is = 61, number of attempts is 1.
# You have guessed the number! It is = 71, number of attempts is 5.
# You have guessed the number! It is = 50, number of attempts is 3.
# You have guessed the number! It is = 51, number of attempts is 4.
# You have guessed the number! It is = 33, number of attempts is 2.
# You have guessed the number! It is = 91, number of attempts is 2.
# You have guessed the number! It is = 21, number of attempts is 7.
# You have guessed the number! It is = 53, number of attempts is 12.
# You have guessed the number! It is = 39, number of attempts is 4.
# You have guessed the number! It is = 66, number of attempts is 5.
# You have guessed the number! It is = 81, number of attempts is 4.
# You have guessed the number! It is = 58, number of attempts is 6.
# You have guessed the number! It is = 53, number of attempts is 1.
# You have guessed the number! It is = 90, number of attempts is 1.
# You have guessed the number! It is = 20, number of attempts is 1.
# You have guessed the number! It is = 95, number of attempts is 2.
# You have guessed the number! It is = 65, number of attempts is 2.
# You have guessed the number! It is = 43, number of attempts is 6.
# You have guessed the number! It is = 48, number of attempts is 1.
# You have guessed the number! It is = 22, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 1.
# You have guessed the number! It is = 2, number of attempts is 2.
# You have guessed the number! It is = 90, number of attempts is 1.
# You have guessed the number! It is = 39, number of attempts is 4.
# You have guessed the number! It is = 13, number of attempts is 1.
# You have guessed the number! It is = 19, number of attempts is 6.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 89, number of attempts is 3.
# You have guessed the number! It is = 91, number of attempts is 1.
# You have guessed the number! It is = 84, number of attempts is 2.
# You have guessed the number! It is = 40, number of attempts is 3.
# You have guessed the number! It is = 99, number of attempts is 1.
# You have guessed the number! It is = 16, number of attempts is 1.
# You have guessed the number! It is = 38, number of attempts is 1.
# You have guessed the number! It is = 97, number of attempts is 1.
# You have guessed the number! It is = 37, number of attempts is 2.
# You have guessed the number! It is = 99, number of attempts is 5.
# You have guessed the number! It is = 2, number of attempts is 3.
# You have guessed the number! It is = 33, number of attempts is 3.
# You have guessed the number! It is = 31, number of attempts is 1.
# You have guessed the number! It is = 8, number of attempts is 6.
# You have guessed the number! It is = 51, number of attempts is 9.
# You have guessed the number! It is = 51, number of attempts is 1.
# You have guessed the number! It is = 33, number of attempts is 3.
# You have guessed the number! It is = 44, number of attempts is 15.
# You have guessed the number! It is = 42, number of attempts is 8.
# You have guessed the number! It is = 70, number of attempts is 1.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 98, number of attempts is 5.
# You have guessed the number! It is = 52, number of attempts is 4.
# You have guessed the number! It is = 31, number of attempts is 2.
# You have guessed the number! It is = 83, number of attempts is 3.
# You have guessed the number! It is = 50, number of attempts is 4.
# You have guessed the number! It is = 82, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 4.
# You have guessed the number! It is = 96, number of attempts is 1.
# You have guessed the number! It is = 72, number of attempts is 2.
# You have guessed the number! It is = 22, number of attempts is 1.
# You have guessed the number! It is = 19, number of attempts is 2.
# You have guessed the number! It is = 47, number of attempts is 6.
# You have guessed the number! It is = 45, number of attempts is 2.
# You have guessed the number! It is = 92, number of attempts is 1.
# You have guessed the number! It is = 10, number of attempts is 1.
# You have guessed the number! It is = 5, number of attempts is 4.
# You have guessed the number! It is = 78, number of attempts is 1.
# You have guessed the number! It is = 64, number of attempts is 1.
# You have guessed the number! It is = 24, number of attempts is 2.
# You have guessed the number! It is = 96, number of attempts is 1.
# You have guessed the number! It is = 60, number of attempts is 3.
# You have guessed the number! It is = 65, number of attempts is 1.
# You have guessed the number! It is = 83, number of attempts is 3.
# You have guessed the number! It is = 32, number of attempts is 1.
# You have guessed the number! It is = 2, number of attempts is 2.
# You have guessed the number! It is = 85, number of attempts is 5.
# You have guessed the number! It is = 79, number of attempts is 1.
# You have guessed the number! It is = 69, number of attempts is 3.
# You have guessed the number! It is = 55, number of attempts is 1.
# You have guessed the number! It is = 26, number of attempts is 5.
# You have guessed the number! It is = 84, number of attempts is 3.
# You have guessed the number! It is = 28, number of attempts is 3.
# You have guessed the number! It is = 57, number of attempts is 4.
# You have guessed the number! It is = 93, number of attempts is 2.
# You have guessed the number! It is = 9, number of attempts is 3.
# You have guessed the number! It is = 56, number of attempts is 3.
# You have guessed the number! It is = 77, number of attempts is 2.
# You have guessed the number! It is = 47, number of attempts is 1.
# You have guessed the number! It is = 50, number of attempts is 3.
# You have guessed the number! It is = 12, number of attempts is 2.
# You have guessed the number! It is = 9, number of attempts is 1.
# You have guessed the number! It is = 62, number of attempts is 11.
# You have guessed the number! It is = 75, number of attempts is 1.
# You have guessed the number! It is = 24, number of attempts is 1.
# You have guessed the number! It is = 89, number of attempts is 1.
# You have guessed the number! It is = 90, number of attempts is 4.
# You have guessed the number! It is = 83, number of attempts is 2.
# You have guessed the number! It is = 83, number of attempts is 3.
# You have guessed the number! It is = 6, number of attempts is 6.
# You have guessed the number! It is = 43, number of attempts is 4.
# You have guessed the number! It is = 47, number of attempts is 2.
# You have guessed the number! It is = 22, number of attempts is 2.
# You have guessed the number! It is = 52, number of attempts is 4.
# You have guessed the number! It is = 74, number of attempts is 3.
# You have guessed the number! It is = 43, number of attempts is 7.
# You have guessed the number! It is = 14, number of attempts is 5.
# You have guessed the number! It is = 19, number of attempts is 2.
# You have guessed the number! It is = 24, number of attempts is 5.
# You have guessed the number! It is = 46, number of attempts is 1.
# You have guessed the number! It is = 96, number of attempts is 1.
# You have guessed the number! It is = 53, number of attempts is 1.
# You have guessed the number! It is = 34, number of attempts is 3.
# You have guessed the number! It is = 55, number of attempts is 1.
# You have guessed the number! It is = 15, number of attempts is 4.
# You have guessed the number! It is = 58, number of attempts is 2.
# You have guessed the number! It is = 62, number of attempts is 5.
# You have guessed the number! It is = 41, number of attempts is 3.
# You have guessed the number! It is = 73, number of attempts is 5.
# You have guessed the number! It is = 66, number of attempts is 3.
# You have guessed the number! It is = 23, number of attempts is 2.
# You have guessed the number! It is = 3, number of attempts is 1.
# You have guessed the number! It is = 87, number of attempts is 1.
# You have guessed the number! It is = 2, number of attempts is 1.
# You have guessed the number! It is = 73, number of attempts is 1.
# You have guessed the number! It is = 52, number of attempts is 3.
# You have guessed the number! It is = 72, number of attempts is 3.
# You have guessed the number! It is = 88, number of attempts is 2.
# You have guessed the number! It is = 78, number of attempts is 2.
# You have guessed the number! It is = 63, number of attempts is 1.
# You have guessed the number! It is = 49, number of attempts is 3.
# You have guessed the number! It is = 1, number of attempts is 1.
# You have guessed the number! It is = 43, number of attempts is 5.
# You have guessed the number! It is = 40, number of attempts is 14.
# You have guessed the number! It is = 4, number of attempts is 1.
# You have guessed the number! It is = 58, number of attempts is 10.
# You have guessed the number! It is = 44, number of attempts is 1.
# You have guessed the number! It is = 54, number of attempts is 2.
# You have guessed the number! It is = 44, number of attempts is 3.
# You have guessed the number! It is = 75, number of attempts is 1.
# You have guessed the number! It is = 99, number of attempts is 3.
# You have guessed the number! It is = 98, number of attempts is 4.
# You have guessed the number! It is = 76, number of attempts is 1.
# Your algorithm guesses a number on average per 2 attempts.
# 2
